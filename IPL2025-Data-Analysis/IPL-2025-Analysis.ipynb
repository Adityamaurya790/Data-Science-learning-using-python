# %% [markdown]
# # IPL 2025 Data Analysis
#
# ```The Indian Premier League (IPL) is a professional T20 cricket league in India, featuring franchises representing cities. This project explores IPL 2025 match-level data to derive meaningful insights and understand match outcomes, player performances, and team dynamics. These are some of the important columns that we'll focus on for meaningful insights in this project. ```

# %% [markdown]
# -> Column names
#
# * match_id
# * date
# * venue
# * team1
# * team2
# * stage
# * first_innings_score
# * first_innings_overs
# * second_innings_score
# * second_innings_overs
# * match_winner
# * won_by
# * margin_type
# * margin

# %% [markdown]
# ### First we have to load libraries and data set to our notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings 

# warnings.filterwarnings("ignore")

ipl = pd.read_csv('IPL25.csv')
ipl
# Out:
#     match_id        date                  venue                        team1  \
# 0          1  2025-03-22  Eden Gardens, Kolkata        Kolkata Knight Riders
# 1          2  2025-03-23              Hyderabad          Sunrisers Hyderabad
# 2          3  2025-03-23                Chennai               Mumbai Indians
# 3          4  2025-03-24          Visakhapatnam         Lucknow Super Giants
# 4          5  2025-03-25              Ahmedabad                 Punjab Kings
# ..       ...         ...                    ...                          ...
# 69        70  2025-05-27                Lucknow         Lucknow Super Giants
# 70        71  2025-05-29         New Chandigarh                 Punjab Kings
# 71        72  2025-05-30         New Chandigarh               Mumbai Indians
# 72        73  2025-06-01              Ahmedabad               Mumbai Indians
# 73        74  2025-06-03              Ahmedabad  Royal Challengers Bengaluru
#
# ...

# %% [markdown]
# ### Droping Match_id because index is there so no need for that

# %%
ipl.drop('match_id',inplace=True,axis = 1)
ipl
# Out:
#           date                  venue                        team1  \
# 0   2025-03-22  Eden Gardens, Kolkata        Kolkata Knight Riders
# 1   2025-03-23              Hyderabad          Sunrisers Hyderabad
# 2   2025-03-23                Chennai               Mumbai Indians
# 3   2025-03-24          Visakhapatnam         Lucknow Super Giants
# 4   2025-03-25              Ahmedabad                 Punjab Kings
# ..         ...                    ...                          ...
# 69  2025-05-27                Lucknow         Lucknow Super Giants
# 70  2025-05-29         New Chandigarh                 Punjab Kings
# 71  2025-05-30         New Chandigarh               Mumbai Indians
# 72  2025-06-01              Ahmedabad               Mumbai Indians
# 73  2025-06-03              Ahmedabad  Royal Challengers Bengaluru
#
#                           team2        stage first_innings_score  \
# 0   Royal Challengers Bengaluru       League               174/8
# ...

# %% [markdown]
# ### Basic information of the data set

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  74 non-null     object
#  1   venue                 74 non-null     object
#  2   team1                 74 non-null     object
#  3   team2                 74 non-null     object
#  4   stage                 74 non-null     object
#  5   first_innings_score   74 non-null     object
#  6   first_innings_overs   74 non-null     object
#  7   second_innings_score  74 non-null     object
#  8   second_innings_overs  74 non-null     object
#  9   match_winner          74 non-null     object
#  10  won_by                74 non-null     object
#  11  margin_type           71 non-null     object
#  12  margin                71 non-null     object
# dtypes: object(13)
# memory usage: 7.6+ KB

# %% [markdown]
# ### Name of all columns

# %%
ipl.columns
# Out:
# Index(['date', 'venue', 'team1', 'team2', 'stage', 'first_innings_score',
#        'first_innings_overs', 'second_innings_score', 'second_innings_overs',
#        'match_winner', 'won_by', 'margin_type', 'margin'],
#       dtype='object')

# %% [markdown]
# ### size of rows and columns of the dataset

# %%
print('Rows in the dataset are', ipl.shape[0], 'and columns are', ipl.shape[1])
# Out:
# Rows in the dataset are 74 and columns are 13

# %% [markdown]
# ### all null valuse in data set

# %%
ipl.isnull().sum()
# Out:
# date                    0
# venue                   0
# team1                   0
# team2                   0
# stage                   0
# first_innings_score     0
# first_innings_overs     0
# second_innings_score    0
# second_innings_overs    0
# match_winner            0
# won_by                  0
# margin_type             3
# margin                  3
# dtype: int64

# %% [markdown]
# ### filling all null value

# %%
ipl["margin"].fillna(0, inplace=True)
ipl['margin_type'].fillna(0,inplace = True)

# %%
ipl.isnull().sum()
# Out:
# date                    0
# venue                   0
# team1                   0
# team2                   0
# stage                   0
# first_innings_score     0
# first_innings_overs     0
# second_innings_score    0
# second_innings_overs    0
# match_winner            0
# won_by                  0
# margin_type             0
# margin                  0
# dtype: int64

# %% [markdown]
# ### Q1) Which team won the most matches?

# %%
ipl["match_winner"].value_counts()
# Out:
# match_winner
# Royal Challengers Bengaluru    11
# Punjab Kings                   10
# Gujarat Titans                  9
# Mumbai Indians                  9
# Delhi Capitals                  7
# Sunrisers Hyderabad             6
# Lucknow Super Giants            6
# Kolkata Knight Riders           5
# Chennai Super Kings             4
# Rajasthan Royals                4
# No Result                       2
# Match abandoned                 1
# Name: count, dtype: int64

# %%
match_wins = ipl['match_winner'].value_counts()
sns.barplot(y = match_wins.index,x = match_wins.values,palette='viridis')
plt.title("Most match win by team ")
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_22140\2731580088.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y = match_wins.index,x = match_wins.values,palette='viridis')
# Text(0.5, 1.0, 'Most match win by team ')

# %% [markdown]
# ### How do teams win? (Runs vs Wickets)

# %%
sns.countplot(x = ipl['won_by'])
plt.title("Won by")
# Out:
# Text(0.5, 1.0, 'Won by')

# %% [markdown]
# ### get all the stadium that hosted the matchs

# %%
ipl['venue'].unique()
# Out:
# array(['Eden Gardens, Kolkata', 'Hyderabad', 'Chennai', 'Visakhapatnam',
#        'Ahmedabad', 'Guwahati', 'Mumbai', 'Lucknow', 'Bengaluru',
#        'Kolkata', 'New Chandigarh', 'Jaipur', 'Delhi', 'Wankhede, Mumbai',
#        'Dharamsala'], dtype=object)

# %%
ipl
# Out:
#           date                  venue                        team1  \
# 0   2025-03-22  Eden Gardens, Kolkata        Kolkata Knight Riders
# 1   2025-03-23              Hyderabad          Sunrisers Hyderabad
# 2   2025-03-23                Chennai               Mumbai Indians
# 3   2025-03-24          Visakhapatnam         Lucknow Super Giants
# 4   2025-03-25              Ahmedabad                 Punjab Kings
# ..         ...                    ...                          ...
# 69  2025-05-27                Lucknow         Lucknow Super Giants
# 70  2025-05-29         New Chandigarh                 Punjab Kings
# 71  2025-05-30         New Chandigarh               Mumbai Indians
# 72  2025-06-01              Ahmedabad               Mumbai Indians
# 73  2025-06-03              Ahmedabad  Royal Challengers Bengaluru
#
#                           team2        stage first_innings_score  \
# 0   Royal Challengers Bengaluru       League               174/8
# ...

# %% [markdown]
# ### Which venue hosted the most matches?

# %%
sns.countplot(y = ipl['venue'])
plt.title("Stadium with matches played")
# Out:
# Text(0.5, 1.0, 'Stadium with matches played')
